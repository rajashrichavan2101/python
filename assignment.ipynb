# %%
x=20
print(type(x))
# Out:
# <class 'int'>

# %%
y="Rajashri"
print(type(y))
# Out:
# <class 'str'>

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
y=8.5
print(type(y))
# Out:
# <class 'float'>

# %%
x=3+5j
print(type(x))
# Out:
# <class 'complex'>

# %%
l=[10,20,30]
print(type(l))
# Out:
# <class 'list'>

# %%
T=(10,20,30)
print(type(T))
# Out:
# <class 'tuple'>

# %%
S={10,20,30}
print(type(S))
# Out:
# <class 'set'>

# %%
D={"name":"rajashri","roll no":8,"div":"A","dept":"Computer"}
print(type(D))
# Out:
# <class 'dict'>

# %%
l=[10,20,30]
print(l)
# Out:
# [10, 20, 30]

# %%
T=(10,20,30)
print(T)
# Out:
# (10, 20, 30)

# %%
S={10,20,30,20}
print(S)
# Out:
# {10, 20, 30}

# %%
D={"name":"Rajashri","age":21}
print(D)
# Out:
# {'name': 'Rajashri', 'age': 21}

# %%
L=[10,20,30]
T=tuple(L)
print(T)
# Out:
# (10, 20, 30)

# %%
x={10,20,30}
y=tuple(x)
print(y)
# Out:
# (10, 20, 30)

# %%
A=[10,20,30]
B=set(A)
print(B)
# Out:
# {10, 20, 30}

# %%
T=(10,20,30)
S=set(T)
print(S)
# Out:
# {10, 20, 30}

# %%
a=b=c=23
print(a)
print(b)
print(c)
# Out:
# 23
# 23
# 23

# %%
a=89
print(id(a))
# Out:
# 140736248344440

# %%
T=(10,20,30)
L=list(T)
print(L)
# Out:
# [10, 20, 30]
